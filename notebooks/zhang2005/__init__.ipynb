# %% [markdown]
# # zhang2005 / __init__
#
# Notebook gerado a partir de `zhang2005/__init__.py`. O código-fonte original foi preservado.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
for _ in range(4):
    if (PROJECT_ROOT / "zhang2005").is_dir():
        break
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

PROJECT_ROOT

# %%
"""Python replication tools for Lu Zhang (2005), "The Value Premium"."""

from zhang2005.calibration import Calibration, calibrate
from zhang2005.equilibrium import construct_equilibrium
from zhang2005.portfolios import value_premium

__all__ = ["Calibration", "calibrate", "construct_equilibrium", "value_premium"]
